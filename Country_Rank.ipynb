# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data96 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 1996.csv",sep=';', index_col=False, dtype='unicode')

data96
# Out:
#     Rank                         Country            Region Documents  \
# 0      1                   United States  Northern America    363066
# 1      2                  United Kingdom    Western Europe     92424
# 2      3                           Japan    Asiatic Region     90995
# 3      4                         Germany    Western Europe     77551
# 4      5                          France    Western Europe     56623
# ..   ...                             ...               ...       ...
# 210  211  British Indian Ocean Territory            Africa         1
# 211  212                         Comoros            Africa         1
# 212  213             Antigua and Barbuda     Latin America         1
# 213  214     Falkland Islands (Malvinas)     Latin America         1
# 214  215                        Kiribati    Pacific Region         1
#
#     Citable documents Citations Self-citations Citations per document H index  \
# ...

# %%
#Checking for null values
data96.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data97 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 1997.csv",sep=';', index_col=False, dtype='unicode')

data97
# Out:
#     Rank                         Country            Region Documents  \
# 0      1                   United States  Northern America    363055
# 1      2                           Japan    Asiatic Region     97491
# 2      3                  United Kingdom    Western Europe     96990
# 3      4                         Germany    Western Europe     85156
# 4      5                          France    Western Europe     61085
# ..   ...                             ...               ...       ...
# 215  216                        Maldives    Asiatic Region         1
# 216  217  British Indian Ocean Territory            Africa         1
# 217  218        Turks and Caicos Islands     Latin America         1
# 218  219           Sao Tome and Principe            Africa         1
# 219  220                      Cape Verde            Africa         1
#
#     Citable documents Citations Self-citations Citations per document H index  \
# ...

# %%
#Checking for null values
data97.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data98 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 1998.csv",sep=';', index_col=False, dtype='unicode')

data98
# Out:
#     Rank                      Country            Region Documents  \
# 0      1                United States  Northern America    361292
# 1      2               United Kingdom    Western Europe     99153
# 2      3                        Japan    Asiatic Region     98205
# 3      4                      Germany    Western Europe     86505
# 4      5                       France    Western Europe     61735
# ..   ...                          ...               ...       ...
# 211  212                        Nauru    Pacific Region         1
# 212  213                 Cook Islands    Pacific Region         1
# 213  214             Christmas Island    Pacific Region         1
# 214  215  French Southern Territories    Pacific Region         1
# 215  216             Marshall Islands    Pacific Region         1
#
#     Citable documents Citations Self-citations Citations per document H index  \
# 0              348952  17849932        7806300                  49,41    3051
# ...

# %%
#Checking for null values
data98.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data99 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 1999.csv",sep=';', index_col=False, dtype='unicode')

data99
# Out:
#     Rank                                       Country            Region  \
# 0      1                                 United States  Northern America
# 1      2                                         Japan    Asiatic Region
# 2      3                                United Kingdom    Western Europe
# 3      4                                       Germany    Western Europe
# 4      5                                        France    Western Europe
# ..   ...                                           ...               ...
# 209  210                                    San Marino    Western Europe
# 210  211                                  Saint Helena            Africa
# 211  212                                  Cook Islands    Pacific Region
# 212  213              Saint Vincent and the Grenadines     Latin America
# 213  214  South Georgia and the South Sandwich Islands     Latin America
#
#     Documents Citable documents Citations Self-citations  \
# ...

# %%
#Checking for null values
data99.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data00 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2000.csv",sep=';', index_col=False, dtype='unicode')

data00
# Out:
#     Rank                   Country            Region Documents  \
# 0      1             United States  Northern America    373344
# 1      2            United Kingdom    Western Europe    106876
# 2      3                     Japan    Asiatic Region    104745
# 3      4                   Germany    Western Europe     90084
# 4      5                    France    Western Europe     63984
# ..   ...                       ...               ...       ...
# 212  213                   Somalia            Africa         1
# 213  214                  Maldives    Asiatic Region         1
# 214  215        Vatican City State    Western Europe         1
# 215  216                 Gibraltar    Western Europe         1
# 216  217  Turks and Caicos Islands     Latin America         1
#
#     Citable documents Citations Self-citations Citations per document H index  \
# 0              356681  20693606        8759126                  55,43    3051
# ...

# %%
#Checking for null values
data00.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data01 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2001.csv",sep=';', index_col=False, dtype='unicode')

data01
# Out:
#     Rank                      Country            Region Documents  \
# 0      1                United States  Northern America    375232
# 1      2                        Japan    Asiatic Region    104061
# 2      3               United Kingdom    Western Europe    102606
# 3      4                      Germany    Western Europe     92996
# 4      5                        China    Asiatic Region     65539
# ..   ...                          ...               ...       ...
# 213  214  French Southern Territories    Pacific Region         1
# 214  215                  Timor-Leste    Asiatic Region         1
# 215  216                     Kiribati    Pacific Region         1
# 216  217                       Tuvalu    Pacific Region         1
# 217  218                    Gibraltar    Western Europe         1
#
#     Citable documents Citations Self-citations Citations per document H index  \
# 0              356384  20969555        8870659                  55,88    3051
# ...

# %%
#Checking for null values
data01.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data02 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2002.csv",sep=';', index_col=False, dtype='unicode')

data02
# Out:
#     Rank                   Country            Region Documents  \
# 0      1             United States  Northern America    399007
# 1      2                     Japan    Asiatic Region    107529
# 2      3            United Kingdom    Western Europe    106362
# 3      4                   Germany    Western Europe     96229
# 4      5                     China    Asiatic Region     68449
# ..   ...                       ...               ...       ...
# 214  215                Cape Verde            Africa         1
# 215  216   Cocos (Keeling) Islands    Pacific Region         1
# 216  217                  Maldives    Asiatic Region         1
# 217  218          Marshall Islands    Pacific Region         1
# 218  219  Turks and Caicos Islands     Latin America         1
#
#     Citable documents Citations Self-citations Citations per document H index  \
# 0              378109  21807956        9209626                  54,66    3051
# ...

# %%
#Checking for null values
data02.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data03 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2003.csv",sep=';', index_col=False, dtype='unicode')

data03
# Out:
#     Rank                   Country            Region Documents  \
# 0      1             United States  Northern America    439416
# 1      2            United Kingdom    Western Europe    120682
# 2      3                     Japan    Asiatic Region    113594
# 3      4                   Germany    Western Europe    104258
# 4      5                     China    Asiatic Region     81930
# ..   ...                       ...               ...       ...
# 214  215                    Tuvalu    Pacific Region         1
# 215  216    Svalbard and Jan Mayen    Western Europe         1
# 216  217  Turks and Caicos Islands     Latin America         1
# 217  218  Virgin Islands (British)     Latin America         1
# 218  219                     Aruba     Latin America         1
#
#     Citable documents Citations Self-citations Citations per document H index  \
# 0              402062  23176757        9700129                  52,74    3051
# ...

# %%
#Checking for null values
data03.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data04 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2004.csv",sep=';', index_col=False, dtype='unicode')

data04
# Out:
#     Rank                 Country            Region Documents  \
# 0      1           United States  Northern America    473558
# 1      2          United Kingdom    Western Europe    127215
# 2      3                   China    Asiatic Region    116981
# 3      4                   Japan    Asiatic Region    116970
# 4      5                 Germany    Western Europe    110589
# ..   ...                     ...               ...       ...
# 217  218                 Somalia            Africa         2
# 218  219                   Nauru    Pacific Region         1
# 219  220                    Niue    Pacific Region         1
# 220  221                 Tokelau    Pacific Region         1
# 221  222  Svalbard and Jan Mayen    Western Europe         1
#
#     Citable documents Citations Self-citations Citations per document H index  \
# 0              432422  24056454        9996348                   50,8    3051
# ...

# %%
#Checking for null values
data04.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data05 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2005.csv",sep=';', index_col=False, dtype='unicode')

data05
# Out:
#     Rank                   Country            Region Documents  \
# 0      1             United States  Northern America    524695
# 1      2                     China    Asiatic Region    170961
# 2      3            United Kingdom    Western Europe    141415
# 3      4                     Japan    Asiatic Region    128047
# 4      5                   Germany    Western Europe    125454
# ..   ...                       ...               ...       ...
# 220  221              Saint Helena            Africa         1
# 221  222   Republic of South Sudan            Africa         1
# 222  223                    Tuvalu    Pacific Region         1
# 223  224  Turks and Caicos Islands     Latin America         1
# 224  225            Norfolk Island    Pacific Region         1
#
#     Citable documents Citations Self-citations Citations per document H index  \
# 0              467557  24319140       10108859                  46,35    3051
# ...

# %%
#Checking for null values
data05.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data06 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2006.csv",sep=';', index_col=False, dtype='unicode')

data06
# Out:
#     Rank           Country            Region Documents Citable documents  \
# 0      1     United States  Northern America    542539            477108
# 1      2             China    Asiatic Region    201036            199482
# 2      3    United Kingdom    Western Europe    149289            125755
# 3      4             Japan    Asiatic Region    130425            126090
# 4      5           Germany    Western Europe    129765            119444
# ..   ...               ...               ...       ...               ...
# 218  219           Comoros            Africa         2                 2
# 219  220      Cook Islands    Pacific Region         1                 1
# 220  221          Anguilla     Latin America         1                 1
# 221  222             Nauru    Pacific Region         1                 1
# 222  223  Christmas Island    Pacific Region         1                 1
#
#     Citations Self-citations Citations per document H index  Year
# ...

# %%
#Checking for null values
data06.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data07 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2007.csv",sep=';', index_col=False, dtype='unicode')

data07
# Out:
#     Rank                               Country            Region Documents  \
# 0      1                         United States  Northern America    543943
# 1      2                                 China    Asiatic Region    222943
# 2      3                        United Kingdom    Western Europe    157611
# 3      4                               Germany    Western Europe    133436
# 4      5                                 Japan    Asiatic Region    124522
# ..   ...                                   ...               ...       ...
# 223  224                        Norfolk Island    Pacific Region         2
# 224  225        British Indian Ocean Territory            Africa         1
# 225  226             Saint Pierre and Miquelon  Northern America         1
# 226  227  United States Minor Outlying Islands  Northern America         1
# 227  228                                 Aruba     Latin America         1
#
# ...

# %%
#Checking for null values
data07.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data08 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2008.csv",sep=';', index_col=False, dtype='unicode')

data08
# Out:
#     Rank                               Country            Region Documents  \
# 0      1                         United States  Northern America    550578
# 1      2                                 China    Asiatic Region    260862
# 2      3                        United Kingdom    Western Europe    160294
# 3      4                               Germany    Western Europe    138982
# 4      5                                 Japan    Asiatic Region    123004
# ..   ...                                   ...               ...       ...
# 222  223                    Vatican City State    Western Europe         1
# 223  224                        Western Sahara            Africa         1
# 224  225                                 Aruba     Latin America         1
# 225  226                          Saint Helena            Africa         1
# 226  227  United States Minor Outlying Islands  Northern America         1
#
# ...

# %%
#Checking for null values
data08.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data09 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2009.csv",sep=';', index_col=False, dtype='unicode')

data09
# Out:
#     Rank                                       Country            Region  \
# 0      1                                 United States  Northern America
# 1      2                                         China    Asiatic Region
# 2      3                                United Kingdom    Western Europe
# 3      4                                       Germany    Western Europe
# 4      5                                         Japan    Asiatic Region
# ..   ...                                           ...               ...
# 227  228                        Svalbard and Jan Mayen    Western Europe
# 228  229                                          Niue    Pacific Region
# 229  230                                        Tuvalu    Pacific Region
# 230  231  South Georgia and the South Sandwich Islands     Latin America
# 231  232                                      Kiribati    Pacific Region
#
#     Documents Citable documents Citations Self-citations  \
# ...

# %%
#Checking for null values
data09.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data10 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2010.csv",sep=';', index_col=False, dtype='unicode')

data10
# Out:
#     Rank                                       Country            Region  \
# 0      1                                 United States  Northern America
# 1      2                                         China    Asiatic Region
# 2      3                                United Kingdom    Western Europe
# 3      4                                       Germany    Western Europe
# 4      5                                         Japan    Asiatic Region
# ..   ...                                           ...               ...
# 226  227                              Christmas Island    Pacific Region
# 227  228                                      Kiribati    Pacific Region
# 228  229                       Cocos (Keeling) Islands    Pacific Region
# 229  230  South Georgia and the South Sandwich Islands     Latin America
# 230  231                                      Anguilla     Latin America
#
#     Documents Citable documents Citations Self-citations  \
# ...

# %%
#Checking for null values
data10.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data11 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2011.csv",sep=';', index_col=False, dtype='unicode')

data11
# Out:
#     Rank                            Country            Region Documents  \
# 0      1                      United States  Northern America    628804
# 1      2                              China    Asiatic Region    389697
# 2      3                     United Kingdom    Western Europe    180700
# 3      4                            Germany    Western Europe    158058
# 4      5                              Japan    Asiatic Region    132458
# ..   ...                                ...               ...       ...
# 224  225     British Indian Ocean Territory            Africa         1
# 225  226             Svalbard and Jan Mayen    Western Europe         1
# 226  227              Sao Tome and Principe            Africa         1
# 227  228  Heard Island and McDonald Islands    Pacific Region         1
# 228  229                       Saint Helena            Africa         1
#
#     Citable documents Citations Self-citations Citations per document H index  \
# ...

# %%
#Checking for null values
data11.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data12 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2012.csv",sep=';', index_col=False, dtype='unicode')

data12
# Out:
#     Rank                               Country            Region Documents  \
# 0      1                         United States  Northern America    670919
# 1      2                                 China    Asiatic Region    416228
# 2      3                        United Kingdom    Western Europe    197515
# 3      4                               Germany    Western Europe    168417
# 4      5                                 Japan    Asiatic Region    135229
# ..   ...                                   ...               ...       ...
# 221  222             Saint Pierre and Miquelon  Northern America         1
# 222  223  United States Minor Outlying Islands  Northern America         1
# 223  224                                Tuvalu    Pacific Region         1
# 224  225        British Indian Ocean Territory            Africa         1
# 225  226                              Kiribati    Pacific Region         1
#
# ...

# %%
#Checking for null values
data12.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data13 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2013.csv",sep=';', index_col=False, dtype='unicode')

data13
# Out:
#     Rank                                       Country            Region  \
# 0      1                                 United States  Northern America
# 1      2                                         China    Asiatic Region
# 2      3                                United Kingdom    Western Europe
# 3      4                                       Germany    Western Europe
# 4      5                                         Japan    Asiatic Region
# ..   ...                                           ...               ...
# 225  226                             Wallis and Futuna    Pacific Region
# 226  227                                        Tuvalu    Pacific Region
# 227  228                                Norfolk Island    Pacific Region
# 228  229                            Vatican City State    Western Europe
# 229  230  South Georgia and the South Sandwich Islands     Latin America
#
#     Documents Citable documents Citations Self-citations  \
# ...

# %%
#Checking for null values
data13.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data14 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2014.csv",sep=';', index_col=False, dtype='unicode')

data14
# Out:
#     Rank                                       Country            Region  \
# 0      1                                 United States  Northern America
# 1      2                                         China    Asiatic Region
# 2      3                                United Kingdom    Western Europe
# 3      4                                       Germany    Western Europe
# 4      5                                         India    Asiatic Region
# ..   ...                                           ...               ...
# 225  226                                 Bouvet Island    Western Europe
# 226  227  South Georgia and the South Sandwich Islands     Latin America
# 227  228                                       Tokelau    Pacific Region
# 228  229                                Norfolk Island    Pacific Region
# 229  230                                       Curaçao     Latin America
#
#     Documents Citable documents Citations Self-citations  \
# ...

# %%
#Checking for null values
data14.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data15 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2015.csv",sep=';', index_col=False, dtype='unicode')

data15
# Out:
#     Rank                 Country            Region Documents  \
# 0      1           United States  Northern America    699051
# 1      2                   China    Asiatic Region    464158
# 2      3          United Kingdom    Western Europe    209395
# 3      4                 Germany    Western Europe    180289
# 4      5                   India    Asiatic Region    144731
# ..   ...                     ...               ...       ...
# 227  228      Vatican City State    Western Europe         2
# 228  229                Pitcairn    Pacific Region         1
# 229  230                 Mayotte            Africa         1
# 230  231                 Tokelau    Pacific Region         1
# 231  232  Svalbard and Jan Mayen    Western Europe         1
#
#     Citable documents Citations Self-citations Citations per document H index  \
# 0              578104  19856656        7819940                  28,41    3051
# ...

# %%
#Checking for null values
data15.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data16 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2016.csv",sep=';', index_col=False, dtype='unicode')

data16
# Out:
#     Rank                                       Country            Region  \
# 0      1                                 United States  Northern America
# 1      2                                         China    Asiatic Region
# 2      3                                United Kingdom    Western Europe
# 3      4                                       Germany    Western Europe
# 4      5                                         India    Asiatic Region
# ..   ...                                           ...               ...
# 226  227             Heard Island and McDonald Islands    Pacific Region
# 227  228  South Georgia and the South Sandwich Islands     Latin America
# 228  229                     Saint Pierre and Miquelon  Northern America
# 229  230                                          Niue    Pacific Region
# 230  231                British Indian Ocean Territory            Africa
#
#     Documents Citable documents Citations Self-citations  \
# ...

# %%
#Checking for null values
data16.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data17 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2017.csv",sep=';', index_col=False, dtype='unicode')

data17
# Out:
#     Rank                               Country            Region Documents  \
# 0      1                         United States  Northern America    725464
# 1      2                                 China    Asiatic Region    547249
# 2      3                        United Kingdom    Western Europe    229321
# 3      4                               Germany    Western Europe    190679
# 4      5                                 India    Asiatic Region    164420
# ..   ...                                   ...               ...       ...
# 227  228        British Indian Ocean Territory            Africa         1
# 228  229                     Wallis and Futuna    Pacific Region         1
# 229  230                      Christmas Island    Pacific Region         1
# 230  231  United States Minor Outlying Islands  Northern America         1
# 231  232                               Tokelau    Pacific Region         1
#
# ...

# %%
#Checking for null values
data17.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data18 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2018.csv",sep=';', index_col=False, dtype='unicode')

data18
# Out:
#     Rank                         Country            Region Documents  \
# 0      1                   United States  Northern America    735118
# 1      2                           China    Asiatic Region    607183
# 2      3                  United Kingdom    Western Europe    230806
# 3      4                         Germany    Western Europe    192871
# 4      5                           India    Asiatic Region    180438
# ..   ...                             ...               ...       ...
# 229  230     French Southern Territories    Pacific Region         1
# 230  231                         Tokelau    Pacific Region         1
# 231  232  British Indian Ocean Territory            Africa         1
# 232  233                            Niue    Pacific Region         1
# 233  234                        Pitcairn    Pacific Region         1
#
#     Citable documents Citations Self-citations Citations per document H index  \
# ...

# %%
#Checking for null values
data18.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data19 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2019.csv",sep=';', index_col=False, dtype='unicode')

data19
# Out:
#     Rank                                       Country            Region  \
# 0      1                                 United States  Northern America
# 1      2                                         China    Asiatic Region
# 2      3                                United Kingdom    Western Europe
# 3      4                                         India    Asiatic Region
# 4      5                                       Germany    Western Europe
# ..   ...                                           ...               ...
# 227  228                             Wallis and Futuna    Pacific Region
# 228  229                                         Nauru    Pacific Region
# 229  230  South Georgia and the South Sandwich Islands     Latin America
# 230  231                                 Bouvet Island    Western Europe
# 231  232          United States Minor Outlying Islands  Northern America
#
#     Documents Citable documents Citations Self-citations  \
# ...

# %%
#Checking for null values
data19.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data20 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2020.csv",sep=';', index_col=False, dtype='unicode')

data20
# Out:
#     Rank                                       Country            Region  \
# 0      1                                         China    Asiatic Region
# 1      2                                 United States  Northern America
# 2      3                                United Kingdom    Western Europe
# 3      4                                         India    Asiatic Region
# 4      5                                       Germany    Western Europe
# ..   ...                                           ...               ...
# 229  230                                Norfolk Island    Pacific Region
# 230  231  South Georgia and the South Sandwich Islands     Latin America
# 231  232                                          Niue    Pacific Region
# 232  233                   French Southern Territories    Pacific Region
# 233  234                                       Tokelau    Pacific Region
#
#     Documents Citable documents Citations Self-citations  \
# ...

# %%
#Checking for null values
data20.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data21 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2021.csv",sep=';', index_col=False, dtype='unicode')

data21
# Out:
#     Rank                    Country            Region Documents  \
# 0      1                      China    Asiatic Region    886996
# 1      2              United States  Northern America    758974
# 2      3             United Kingdom    Western Europe    249665
# 3      4                      India    Asiatic Region    247903
# 4      5                    Germany    Western Europe    215397
# ..   ...                        ...               ...       ...
# 230  231                      Nauru    Pacific Region         1
# 231  232       Netherlands Antilles     Latin America         1
# 232  233             Norfolk Island    Pacific Region         1
# 233  234  Saint Pierre and Miquelon  Northern America         1
# 234  235             Western Sahara            Africa         1
#
#     Citable documents Citations Self-citations Citations per document H index  \
# 0              867611   8308936        5698172                   9,37    1333
# ...

# %%
#Checking for null values
data21.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data22 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2022.csv",sep=';', index_col=False, dtype='unicode')

data22
# Out:
#     Rank                               Country            Region Documents  \
# 0      1                                 China    Asiatic Region   1028625
# 1      2                         United States  Northern America    724534
# 2      3                                 India    Asiatic Region    283374
# 3      4                        United Kingdom    Western Europe    241135
# 4      5                               Germany    Western Europe    210224
# ..   ...                                   ...               ...       ...
# 229  230                        Western Sahara            Africa         1
# 230  231                               Tokelau    Pacific Region         1
# 231  232                        Norfolk Island    Pacific Region         1
# 232  233                  Netherlands Antilles     Latin America         1
# 233  234  United States Minor Outlying Islands  Northern America         1
#
# ...

# %%
#Checking for null values
data22.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
data23 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_COUNTRY_RISK\scimagojr country rank 2023.csv",sep=';', index_col=False, dtype='unicode')

data23
# Out:
#     Rank                               Country            Region Documents  \
# 0      1                                 China    Asiatic Region   1043131
# 1      2                         United States  Northern America    714412
# 2      3                                 India    Asiatic Region    306647
# 3      4                        United Kingdom    Western Europe    238568
# 4      5                               Germany    Western Europe    202397
# ..   ...                                   ...               ...       ...
# 229  230                               Tokelau    Pacific Region         2
# 230  231  United States Minor Outlying Islands  Northern America         1
# 231  232                                  Niue    Pacific Region         1
# 232  233        British Indian Ocean Territory            Africa         1
# 233  234                     Wallis and Futuna    Pacific Region         1
#
# ...

# %%
#Checking for null values
data23.isna().sum()
# Out:
# Rank                      0
# Country                   0
# Region                    0
# Documents                 0
# Citable documents         0
# Citations                 0
# Self-citations            0
# Citations per document    0
# H index                   0
# Year                      0
# dtype: int64

# %%
vertical_all = pd.concat([data96,data97,data98,data99,data00,data01,data02,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12,data13,data14,data15,data16,data17,data18,data19,data20,data21,data22,data23], axis=0)

# %%
vertical_all.head(25)
# Out:
#    Rank             Country            Region Documents Citable documents  \
# 0     1       United States  Northern America    363066            352894
# 1     2      United Kingdom    Western Europe     92424             86784
# 2     3               Japan    Asiatic Region     90995             89817
# 3     4             Germany    Western Europe     77551             76116
# 4     5              France    Western Europe     56623             55329
# 5     6              Canada  Northern America     43740             42829
# 6     7               Italy    Western Europe     40429             39193
# 7     8  Russian Federation    Eastern Europe     32416             32275
# 8     9               China    Asiatic Region     30885             30776
# 9    10           Australia    Pacific Region     25745             24863
# 10   11               Spain    Western Europe     25141             24420
# 11   12         Netherlands    Western Europe     23378             22813
# ...

# %%
vertical_all.tail(25)
# Out:
#     Rank                               Country            Region Documents  \
# 209  210              Turks and Caicos Islands     Latin America        16
# 210  211                          Cook Islands    Pacific Region        16
# 211  212      Saint Vincent and the Grenadines     Latin America        15
# 212  213                              Kiribati    Pacific Region        14
# 213  214                    Vatican City State    Western Europe        14
# 214  215                  Saint Martin (Dutch)     Latin America        12
# 215  216                           Saint Lucia     Latin America        12
# 216  217                               Mayotte            Africa        11
# 217  218                              Anguilla     Latin America        11
# 218  219                  Netherlands Antilles     Latin America        10
# 219  220                      Marshall Islands    Pacific Region         7
# ...

# %%
vertical_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6339 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rank                    6339 non-null   object
#  1   Country                 6339 non-null   object
#  2   Region                  6339 non-null   object
#  3   Documents               6339 non-null   object
#  4   Citable documents       6339 non-null   object
#  5   Citations               6339 non-null   object
#  6   Self-citations          6339 non-null   object
#  7   Citations per document  6339 non-null   object
#  8   H index                 6339 non-null   object
#  9   Year                    4972 non-null   object
#  10  Year                    1367 non-null   object
# dtypes: object(11)
# memory usage: 594.3+ KB

# %%
#Remove last column
vertical_all = vertical_all.iloc[:,:-1]

# %%
vertical_all.head(5)
# Out:
#   Rank         Country            Region Documents Citable documents  \
# 0    1   United States  Northern America    363066            352894
# 1    2  United Kingdom    Western Europe     92424             86784
# 2    3           Japan    Asiatic Region     90995             89817
# 3    4         Germany    Western Europe     77551             76116
# 4    5          France    Western Europe     56623             55329
#
#   Citations Self-citations Citations per document H index  Year
# 0  15977965        7067121                  44,01    3051  1996
# 1   3414712         728427                  36,95    1928  1996
# 2   2109846         569606                  23,19    1301  1996
# 3   2607177         588296                  33,62    1690  1996
# 4   1865217         371759                  32,94    1514  1996

# %%
vertical_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6339 entries, 0 to 233
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rank                    6339 non-null   object
#  1   Country                 6339 non-null   object
#  2   Region                  6339 non-null   object
#  3   Documents               6339 non-null   object
#  4   Citable documents       6339 non-null   object
#  5   Citations               6339 non-null   object
#  6   Self-citations          6339 non-null   object
#  7   Citations per document  6339 non-null   object
#  8   H index                 6339 non-null   object
#  9   Year                    4972 non-null   object
# dtypes: object(10)
# memory usage: 544.8+ KB

# %% [markdown]
# As seen in the above table the variable 'Year' presents an important number of null values

# %%
vertical_all['Year'].unique()
# Out:
# array(['1996', '1997', '1998', '1999', '2000', '2001', nan, '2003',
#        '2004', '2006', '2007', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2018', '2020', '2021', '2022', '2023'],
#       dtype=object)

# %%
vertical_all['Year']=vertical_all['Year'].str.replace("nan","2002")

# %%
vertical_all['Year'].unique()
# Out:
# array(['1996', '1997', '1998', '1999', '2000', '2001', nan, '2003',
#        '2004', '2006', '2007', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2018', '2020', '2021', '2022', '2023'],
#       dtype=object)

# %%
vertical_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6339 entries, 0 to 233
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rank                    6339 non-null   object
#  1   Country                 6339 non-null   object
#  2   Region                  6339 non-null   object
#  3   Documents               6339 non-null   object
#  4   Citable documents       6339 non-null   object
#  5   Citations               6339 non-null   object
#  6   Self-citations          6339 non-null   object
#  7   Citations per document  6339 non-null   object
#  8   H index                 6339 non-null   object
#  9   Year                    4972 non-null   object
# dtypes: object(10)
# memory usage: 544.8+ KB

# %%
vertical_all.to_csv(r'C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\clean_country_rank.json', encoding='utf-8')

# %% [markdown]
# Exploratory Data Analysis-EDA

# %%
#Describe DataFrame.
vertical_all.describe()
# Out:
#         Rank        Country  Region Documents Citable documents Citations  \
# count   6339           6339    6339      6339              6339      6339
# unique   235            243       9      2850              2803      4916
# top        1  United States  Africa         1                 1         0
# freq      28             28    1555       199               198        53
#
#        Self-citations Citations per document H index  Year
# count            6339                   6339    6339  4972
# unique           3244                   3440     186    22
# top                 0                      0      48  2021
# freq              429                     53     111   235

# %%
#Covert DF to numeric
vertical_all=vertical_all.apply(pd.to_numeric, errors='ignore')
# Out:
# C:\Users\torra\AppData\Local\Temp\ipykernel_17044\1596916935.py:2: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   vertical_all=vertical_all.apply(pd.to_numeric, errors='ignore')

# %%
vertical_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6339 entries, 1996 to 2023
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rank                    6339 non-null   int64
#  1   Country                 6339 non-null   object
#  2   Region                  6339 non-null   object
#  3   Documents               6339 non-null   int64
#  4   Citable documents       6339 non-null   int64
#  5   Citations               6339 non-null   int64
#  6   Self-citations          6339 non-null   int64
#  7   Citations per document  6339 non-null   object
#  8   H index                 6339 non-null   int64
# dtypes: int64(6), object(3)
# memory usage: 495.2+ KB

# %%
#Descriptive Statistics
vertical_all.describe()
# Out:
#               Rank     Documents  Citable documents     Citations  \
# count  6339.000000  6.339000e+03       6.339000e+03  6.339000e+03
# mean    113.794447  1.263477e+04       1.155613e+04  2.970045e+05
# std      65.526514  5.582533e+04       5.064322e+04  1.488894e+06
# min       1.000000  1.000000e+00       0.000000e+00  0.000000e+00
# 25%      57.000000  3.150000e+01       2.900000e+01  6.300000e+02
# 50%     114.000000  2.630000e+02       2.470000e+02  5.291000e+03
# 75%     170.000000  3.079500e+03       2.923500e+03  4.960100e+04
# max     235.000000  1.043131e+06       1.018423e+06  2.431914e+07
#
#        Self-citations      H index
# count    6.339000e+03  6339.000000
# mean     8.252885e+04   296.342325
# std      6.047646e+05   397.460597
# min      0.000000e+00     2.000000
# 25%      3.400000e+01    67.000000
# 50%      4.480000e+02   140.000000
# 75%      6.952000e+03   325.000000
# max      1.010886e+07  3051.000000

# %%
numeric_CR = vertical_all.select_dtypes(include=[np.number])
categorical_CR = vertical_all.select_dtypes(exclude=[np.number])

# %%
vertical_all.tail()
# Out:
#      Rank                               Country            Region Documents  \
# Year
# 2023  230                               Tokelau    Pacific Region         2
# 2023  231  United States Minor Outlying Islands  Northern America         1
# 2023  232                                  Niue    Pacific Region         1
# 2023  233        British Indian Ocean Territory            Africa         1
# 2023  234                     Wallis and Futuna    Pacific Region         1
#
#      Citable documents Citations Self-citations Citations per document H index
# Year
# 2023                 2         4              0                      2       5
# 2023                 1         0              0                      0      12
# 2023                 1         4              0                      4      11
# 2023                 0         4              0                      4      14
# 2023                 1         0              0                      0       8

# %%
sns.pairplot(numeric_CR)
# Out:
# C:\Users\torra\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\torra\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
corr_matrix=numeric_CR.select_dtypes(include=[np.number]).corr() 
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %% [markdown]
# Dickey-Fuller test (unit root)
# We conduct the following test in our main variables to know if our data is stationary or not.
# p-value > 0.05: Fail to reject the null hypothesis (H0), the data has a unit root and is non-stationary.
# p-value <= 0.05: Reject the null hypothesis (H0), the data does not have a unit root and is stationary.

# %%
Hindex0 = numeric_CR['H index']

# %%
from statsmodels.tsa.stattools import adfuller
X = Hindex0[1:].values

result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -11.184790
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %% [markdown]
# Taking into consideration the p-value (0.00) of the variable H-index0 , we reject the null hypothesis, the data does not have unit root and is stationary.

# %%
Hindex1 = numeric_CR['H index'] - numeric_CR['H index'].shift(1)

# %%
from statsmodels.tsa.stattools import adfuller
X = Hindex1[1:].values

result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -21.175509
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %% [markdown]
# Taking into consideration the p-value (0.00) of the variable H-index1 lag(1), we reject the null hypothesis, the data does not have unit root and is stationary.

# %% [markdown]
# We conclude that the variable H-index does not present seasonality.

# %%
Citations0 = numeric_CR['Citations'] 
Citations1 = numeric_CR['Citations'] - numeric_CR['Citations'].shift(1)

# %%
X = Citations0[1:].values

result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -20.298355
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %% [markdown]
# Taking into consideration the p-value (0.00) of the variable Citations, we reject the null hypothesis, the data does not have unit root and is stationary.

# %%
X = Citations1[1:].values

result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -21.330240
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %% [markdown]
# Taking into consideration the p-value (0.00) of the variable Citations1, we reject the null hypothesis, the data does not have unit root and is stationary.
# We conclude that the variable Citations does not present seasonality.
