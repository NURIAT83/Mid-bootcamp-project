# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
journals03 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_Journals\scimagojr 2003.csv",sep=';', index_col=False, dtype='unicode')
journals04 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_Journals\scimagojr 2004.csv",sep=';', index_col=False, dtype='unicode')
journals05 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_Journals\scimagojr 2005.csv",sep=';', index_col=False, dtype='unicode')
journals06 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_Journals\scimagojr 2006.csv",sep=';', index_col=False, dtype='unicode')
journals07 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_Journals\scimagojr 2007.csv",sep=';', index_col=False, dtype='unicode')
journals08 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_Journals\scimagojr 2008.csv",sep=';', index_col=False, dtype='unicode')
journals09 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_Journals\scimagojr 2009.csv",sep=';', index_col=False, dtype='unicode')
journals10 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_Journals\scimagojr 2010.csv",sep=';', index_col=False, dtype='unicode')
journals11 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_Journals\scimagojr 2011.csv",sep=';', index_col=False, dtype='unicode')
journals12 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_Journals\scimagojr 2012.csv",sep=';', index_col=False, dtype='unicode')
journals13 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_Journals\scimagojr 2013.csv",sep=';', index_col=False, dtype='unicode')
journals14 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_Journals\scimagojr 2014.csv",sep=';', index_col=False, dtype='unicode')
journals15 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_Journals\scimagojr 2015.csv",sep=';', index_col=False, dtype='unicode')
journals16 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_Journals\scimagojr 2016.csv",sep=';', index_col=False, dtype='unicode')
journals17 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_Journals\scimagojr 2017.csv",sep=';', index_col=False, dtype='unicode')
journals18 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_Journals\scimagojr 2018.csv",sep=';', index_col=False, dtype='unicode')
journals19 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_Journals\scimagojr 2019.csv",sep=';', index_col=False, dtype='unicode')
journals20 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_Journals\scimagojr 2020.csv",sep=';', index_col=False, dtype='unicode')
journals21 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_Journals\scimagojr 2021.csv",sep=';', index_col=False, dtype='unicode')
journals22 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_Journals\scimagojr 2022.csv",sep=';', index_col=False, dtype='unicode')
journals23 = pd.read_csv(r"C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\SCIMAGO_Journals\scimagojr 2023.csv",sep=';', index_col=False, dtype='unicode')

# %%
journals_hist=[journals03,journals04,journals05,journals06,journals07,journals08,journals09,journals10,journals11,journals12,journals13,journals14,journals15,journals16,journals17,journals18,journals19,journals20,journals21,journals22,journals23]



journals_total=pd.concat(journals_hist, axis=0).sort_values(['Year', 'Rank']).reset_index(drop=True)

# %%
journals_total.head()
# Out:
#     Rank Sourceid                                         Title     Type  \
# 0      1    20651                   Annual Review of Immunology  journal
# 1     10    29431                Quarterly Journal of Economics  journal
# 2    100    19939                       Trends in Neurosciences  journal
# 3   1000    20386                      Insect Molecular Biology  journal
# 4  10000    18976  Medizinische Klinik (Munich, Germany : 1983)  journal
#
#                  Issn     SJR SJR Best Quartile H index Total Docs  \
# 0  15453278, 07320582  37,995                Q1     328         25
# 1  00335533, 15314650  16,387                Q1     306         40
# 2  01662236, 1878108X   6,238                Q1     318        139
# 3  13652583, 09621075   1,682                Q1     102         70
# 4  07235003, 16156722    0,19                Q2      30        143
#
#   Total Docs. (3years)  ... Cites / Doc. (2years) Ref. / Doc.         Country  \
# ...

# %%
journals_total.isna().sum()
# Out:
# Rank                           0
# Sourceid                       0
# Title                          0
# Type                           0
# Issn                           0
# SJR                        46026
# SJR Best Quartile              0
# H index                        0
# Total Docs                     0
# Total Docs. (3years)           0
# Total Refs.                    0
# Total Cites (3years)           0
# Citable Docs. (3years)         0
# Cites / Doc. (2years)          0
# Ref. / Doc.                    0
# Country                        0
# Region                         0
# Publisher                  96967
# Coverage                   89895
# Categories                     4
# Areas                          4
# Year                      164539
# Year                      452210
# dtype: int64

# %%
journals_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616748 entries, 0 to 616747
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Rank                    616748 non-null  object
#  1   Sourceid                616748 non-null  object
#  2   Title                   616748 non-null  object
#  3   Type                    616748 non-null  object
#  4   Issn                    616748 non-null  object
#  5   SJR                     570722 non-null  object
#  6   SJR Best Quartile       616748 non-null  object
#  7   H index                 616748 non-null  object
#  8   Total Docs              616748 non-null  object
#  9   Total Docs. (3years)    616748 non-null  object
#  10  Total Refs.             616748 non-null  object
#  11  Total Cites (3years)    616748 non-null  object
#  12  Citable Docs. (3years)  616748 non-null  object
#  13  Cites / Doc. (2years)   616748 non-null  object
# ...

# %%
#Remove last column
journals_total = journals_total.iloc[:,:-1]

# %%
journals_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616748 entries, 0 to 616747
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Rank                    616748 non-null  object
#  1   Sourceid                616748 non-null  object
#  2   Title                   616748 non-null  object
#  3   Type                    616748 non-null  object
#  4   Issn                    616748 non-null  object
#  5   SJR                     570722 non-null  object
#  6   SJR Best Quartile       616748 non-null  object
#  7   H index                 616748 non-null  object
#  8   Total Docs              616748 non-null  object
#  9   Total Docs. (3years)    616748 non-null  object
#  10  Total Refs.             616748 non-null  object
#  11  Total Cites (3years)    616748 non-null  object
#  12  Citable Docs. (3years)  616748 non-null  object
#  13  Cites / Doc. (2years)   616748 non-null  object
# ...

# %%
journals_total2 = journals_total[['Rank', 'Sourceid','Title','Type','H index','Total Docs','Total Refs.','Ref. / Doc.','Country','Region', 'Publisher','Areas','Year']]

# %%
journals_total2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616748 entries, 0 to 616747
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Rank         616748 non-null  object
#  1   Sourceid     616748 non-null  object
#  2   Title        616748 non-null  object
#  3   Type         616748 non-null  object
#  4   H index      616748 non-null  object
#  5   Total Docs   616748 non-null  object
#  6   Total Refs.  616748 non-null  object
#  7   Ref. / Doc.  616748 non-null  object
#  8   Country      616748 non-null  object
#  9   Region       616748 non-null  object
#  10  Publisher    519781 non-null  object
#  11  Areas        616744 non-null  object
#  12  Year         452209 non-null  object
# dtypes: object(13)
# memory usage: 61.2+ MB

# %%
journals_total2.tail(20)
# Out:
#         Rank     Sourceid                                              Title  \
# 616728  9996  12800154717  Proceedings - 7th IEEE International Symposium...
# 616729  9996        21960                           Supramolecular Chemistry
# 616730  9996  19400158382                     Saudi Journal of Ophthalmology
# 616731  9996  11200153508                                     Memory Studies
# 616732  9996        18542                      American Journal of Philology
# 616733  9997        91796                           Progress in Orthodontics
# 616734  9997  21100276234  2013 10th IEEE International Conference on Adv...
# 616735  9997        18675                                 Teaching Sociology
# 616736  9997  21100900141           Pixel-Bit, Revista de Medios y Educacion
# 616737  9997  17700156736                                    Energy Procedia
# 616738  9998        12982            Prosthetics and Orthotics International
# ...

# %%
#Covert DF to numeric
journals_total2=journals_total2.apply(pd.to_numeric, errors='ignore')
# Out:
# C:\Users\torra\AppData\Local\Temp\ipykernel_9384\160047316.py:2: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   journals_total2=journals_total2.apply(pd.to_numeric, errors='ignore')

# %%
#There are journals that have very little  references and total documents, which are not representative and may damage our analysis as outliers.
#We drop all journals that have less than 150 total documents and less than a 1000 total references.
journals_total2 = journals_total2[(journals_total2['Total Docs'] >= 150) & (journals_total2['Total Refs.'] >= 1000)]

# %%
#Remove all type of rows that are not journals entries, such as conferences 
journals_total2=journals_total2[(journals_total2['Type']=='journal')]

# %%
#journals_total2['Year']=journals_total2['Year'].replace(".0","")
journals_total2['Year'] = journals_total2['Year'].fillna(0)


journals_total2['Year'] = journals_total2['Year'].astype('Int64')

# %%
journals_total2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67248 entries, 14 to 616707
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         67248 non-null  int64
#  1   Sourceid     67248 non-null  int64
#  2   Title        67248 non-null  object
#  3   Type         67248 non-null  object
#  4   H index      67248 non-null  int64
#  5   Total Docs   67248 non-null  int64
#  6   Total Refs.  67248 non-null  int64
#  7   Ref. / Doc.  67248 non-null  object
#  8   Country      67248 non-null  object
#  9   Region       67248 non-null  object
#  10  Publisher    66364 non-null  object
#  11  Areas        67248 non-null  object
#  12  Year         67248 non-null  Int64
# dtypes: Int64(1), int64(5), object(7)
# memory usage: 7.2+ MB

# %%
journals_total2.head()
# Out:
#      Rank  Sourceid                                              Title  \
# 14   1001     19210                     Journal of Experimental Botany
# 24  10019     21859   Enfermedades Infecciosas y Microbiologia Clinica
# 25   1002     23086  Journal of Pharmacology and Experimental Thera...
# 36   1003     20268                      Microbiology (United Kingdom)
# 41  10034     24143  Pan Tao Ti Hsueh Pao/Chinese Journal of Semico...
#
#        Type  H index  Total Docs  Total Refs. Ref. / Doc.         Country  \
# 14  journal      293         302        12124       40,15  United Kingdom
# 24  journal       47         170         3480       20,47           Spain
# 25  journal      244         610        22972       37,66   United States
# 36  journal      204         355        15640       44,06  United Kingdom
# 41  journal       17         214         2266       10,59           China
#
#               Region                                          Publisher  \
# ...

# %%
#Save the clean file before EDA
journals_total2.to_csv(r'C:\Users\torra\IH-Labs\Mid_Bootcamp_Project\clean_journals_rank3.json', encoding='utf-8')

# %% [markdown]
# EXploratory Data Analysis-EDA

# %%
import calplot

# %%
#Describe DataFrame.
journals_total2.describe()
# Out:
#                Rank      Sourceid       H index    Total Docs   Total Refs.  \
# count  67248.000000  6.724800e+04  67248.000000  67248.000000  6.724800e+04
# mean    7300.427106  3.941383e+09    128.077608    407.823043  1.513365e+04
# std     7050.261987  7.753429e+09    105.501041    653.567566  3.362395e+04
# min        3.000000  1.200500e+04      2.000000    150.000000  1.000000e+03
# 25%     2017.000000  1.874200e+04     56.000000    190.000000  5.329000e+03
# 50%     4877.000000  2.482300e+04    108.000000    258.000000  8.481000e+03
# 75%    10586.000000  1.301415e+05    171.000000    407.000000  1.455325e+04
# max    36168.000000  2.110118e+10   1391.000000  31123.000000  1.466116e+06
#
#               Year
# count      67248.0
# mean   1452.754253
# std     902.584233
# min            0.0
# 25%            0.0
# 50%         2009.0
# 75%         2018.0
# max         2023.0

# %%
numeric_JR = journals_total2.select_dtypes(include=[np.number])
categorical_JR = journals_total2.select_dtypes(exclude=[np.number])

# %%
sns.pairplot(numeric_JR)
# Out:
# C:\Users\torra\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\torra\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
corr_matrix=numeric_JR.select_dtypes(include=[np.number]).corr() 
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %% [markdown]
# Dickey-Fuller test (unit root)
# We conduct the following test in our main variables to know if our data is stationary or not.
# p-value > 0.05: Fail to reject the null hypothesis (H0), the data has a unit root and is non-stationary.
# p-value <= 0.05: Reject the null hypothesis (H0), the data does not have a unit root and is stationary.

# %%
Hindex0 = numeric_JR['H index']

# %%
from statsmodels.tsa.stattools import adfuller
X = Hindex0[1:].values

result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))

# %%
Hindex1 = numeric_JR['H index'] - numeric_JR['H index'].shift(1)

# %%
from statsmodels.tsa.stattools import adfuller
X = Hindex1[1:].values

result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))

# %%
Citations0 = numeric_JR['Citations'] 
Citations1 = numeric_JR['Citations'] - numeric_JR['Citations'].shift(1)

# %%
X = Citations1[1:].values

result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
